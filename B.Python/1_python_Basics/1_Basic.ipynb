# %% [markdown]
# Syntax refers to the set of rules that defines the combinattions of symbols that are considered to be correctly structured programs in a language. In simple terms, syntax is about the correct arrangeent of words and symbols in a code.
#
# Symantics refers to the meaning or the interpretaion of the symbols, characters and commands in a language. It is about what the code supposed to do when it runs.

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## python is case sensitive

# %%
name="vrushank"
Name="vrushank"
print(name,Name)
# Out:
# vrushank vrushank

# %% [markdown]
# ## Indentation

# %%
#python uses identation to define the block of code commonly 4 spaces or tab
age = 32
if age > 18:
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %% [markdown]
# ## Line continuation

# %%
total = 1+2+3+4+5+\
6+7
print(total) #backslash helps us to have the code in a single line although it is written in different lines
# Out:
# 28

# %% [markdown]
# ## multiple statements on a single line

# %%
x=5;y=12;z=x+y
print(z)
# Out:
# 17

# %% [markdown]
# ## understand semantics in python

# %%
age=32
print(type(age)) #python allocates the datatype in run time called dynamic allocation
age=6
print(age)
# Out:
# <class 'int'>
# 6

# %%
##name error comes when we have not defined that we want to use
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 ##name error comes when we have not defined that we want to use
# ----> 2 a=b
#
# NameError: name 'b' is not defined
