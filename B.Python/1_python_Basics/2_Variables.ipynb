# %% [markdown]
# # Variables

# %% [markdown]
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In python, variables are created when you assign a value to them, and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.

# %%
a=100

# %%
# declaring and assigning variables
age=32
name="Vrushank"
is_student=True
print("age:",age,"name:",name,"is_student:",is_student)
# Out:
# age: 32 name: Vrushank is_student: True

# %% [markdown]
# ## naming convention
#
# variables names should be descriptive
#
# they must start with a letter or an "-" and contains letter, numbers and underscores
#
# variables names case sensitive
#
# we can't start a variable name starting with integer
#
# we can't use any letter other than A-Z, a-z, 0-9 and _

# %% [markdown]
# ## understaning variable types
# python is dynamically typed, type of a variable is determined at runtime

# %%
age=32             #int
name="Vrushank"    #string
is_student=True    #boolean
height=7.1         #height

# %% [markdown]
# Type conversion

# %%
age=25 #int
str_age=str(age)  #str
print(str_age,type(str_age))
# Out:
# 25 <class 'str'>

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
#but we can't convert string like vrushank into int

height=5.9
h=int(height) 
print(h,type(h)) #work float to int(floor value)

balance=100
b=float(balance)
print(b,type(b)) #work int to float
# Out:
# 5 <class 'int'>
# 100.0 <class 'float'>

# %% [markdown]
# ## Dynamic typing
# python allows the type of variable to change as the program executes

# %%
var=10 #int
var=56.23 #float

# %% [markdown]
# ## Taking input from user
# We can take inputs, but the input is always in string format

# %%
age=input("What is your age:")
print(age,type(age))
# Out:
# 15 <class 'str'>
